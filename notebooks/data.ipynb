# %%
import pandas as pd
import numpy as np
import yfinance as yf
import torch
# import torch_geometric
import sklearn

# %%
stocks = [
    "RELIANCE.NS",
    "TCS.NS",
    "HDFCBANK.NS",
    "ICICIBANK.NS",
    "INFY.NS",
    "HINDUNILVR.NS",
    "ITC.NS",
    "SBIN.NS",
    "BHARTIARTL.NS",
    "KOTAKBANK.NS",

    "LT.NS",
    "AXISBANK.NS",
    "ASIANPAINT.NS",
    "MARUTI.NS",
    "SUNPHARMA.NS",
    "TITAN.NS",
    "ULTRACEMCO.NS",
    "NESTLEIND.NS",
    "BAJFINANCE.NS",
    "HCLTECH.NS",

    "WIPRO.NS",
    "TECHM.NS",
    "POWERGRID.NS",
    "NTPC.NS",
    "ONGC.NS",
    "TATASTEEL.NS",
    "JSWSTEEL.NS",
    "ADANIENT.NS",
    "ADANIPORTS.NS",
    "COALINDIA.NS",

    "TATAMOTORS.NS",
    "M&M.NS",
    "EICHERMOT.NS",
    "HEROMOTOCO.NS",
    "BAJAJ-AUTO.NS",
    "BAJAJFINSV.NS",
    "DRREDDY.NS",
    "CIPLA.NS",
    "DIVISLAB.NS",
    "APOLLOHOSP.NS",

    "BPCL.NS",
    "IOC.NS",
    "GRASIM.NS",
    "BRITANNIA.NS",
    "TATACONSUM.NS",
    "INDUSINDBK.NS",
    "HINDALCO.NS",
    "SHRIRAMFIN.NS",
    "BEL.NS",
    "TRENT.NS"
]

print("Number of stocks:", len(stocks))

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("yfinance:", yf.__version__)
print("torch:", torch.__version__)
# print("PyG:", torch_geometric.__version__)
print("CUDA available:", torch.cuda.is_available())

raw_data = yf.download(
    tickers=stocks,
    period='2y',
    interval="1d",
    auto_adjust=True,
    group_by="column",
    progress=True,
    threads=True
    )
print(raw_data.shape)
print(raw_data.head())
# Out:
# Number of stocks: 50
# pandas: 3.0.5
# numpy: 2.2.6
# yfinance: 1.7.0
# torch: 2.13.0+cpu
# CUDA available: False
# [*******************   40%                       ]  20 of 50 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATAMOTORS.NS"}}}
# [**********************70%*********              ]  35 of 50 completed$TATAMOTORS.NS: No data found, symbol may be delisted
# [*********************100%***********************]  50 of 50 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: No data found, symbol may be delisted
# (501, 251)
# Price          Adj Close        Close                              \
# Ticker     TATAMOTORS.NS  ADANIENT.NS ADANIPORTS.NS APOLLOHOSP.NS
# Date
# 2024-09-11           NaN  2935.082275   1417.698730   6864.580078
# 2024-09-12           NaN  2988.181885   1459.319946   7025.294922
# 2024-09-13           NaN  2965.553467   1439.004883   6982.865723
# 2024-09-16           NaN  2982.087646   1427.707642   6995.002930
# 2024-09-17           NaN  2972.396729   1413.734863   6971.822754
#
# Price                                                              \
# Ticker     ASIANPAINT.NS  AXISBANK.NS BAJAJ-AUTO.NS BAJAJFINSV.NS
# Date
# 2024-09-11   3297.159180  1184.173950  10983.877930   1830.695190
# 2024-09-12   3312.629395  1201.395874  11275.047852   1852.366089
# 2024-09-13   3287.955322  1215.473022  11288.174805   1891.912964
# 2024-09-16   3266.169922  1229.051025  11241.241211   1855.112427
# 2024-09-17   3243.650146  1230.099121  11493.170898   1846.224243
#
# Price                                 ...       Volume                \
# Ticker     BAJFINANCE.NS      BEL.NS  ... SUNPHARMA.NS TATACONSUM.NS
# Date                                  ...
# 2024-09-11    725.589905  284.203003  ...      1701900       1837013
# 2024-09-12    733.763855  287.804291  ...      2744070       2635403
# 2024-09-12           NaN     73191476  2742216  2356422  1337327   572357
# 2024-09-13           NaN     54894255  1458786  1373924  1003355   468707
# 2024-09-16           NaN     32575460  1155120  1060407   386602   502100
# 2024-09-17           NaN     18275113  1699364  1499644   392339   753643
# ...                  ...          ...      ...      ...      ...      ...
# 2026-09-07           NaN     23695657  2297551  2028588   480336  1021019
# 2026-09-08           NaN     24272812  2148114  1575629   432671   588825
# 2026-09-09           NaN     45985325  3370071  1329200   502050   601991
# 2026-09-10           NaN     23334612  2490912  1405653   336565   503802
# 2026-09-11           NaN     31510206  2634124  2007328   403235   677898
#
# Price
# Ticker     ULTRACEMCO.NS  WIPRO.NS
# Date
# 2024-09-11        141341   8261524
# 2024-09-12        455934  15779474
# 2024-09-13        279660  35919706
# 2024-09-16        257856  11088578
# 2024-09-17        202725   8728238
# ...                  ...       ...
# 2026-09-07        214788  10720636
# 2026-09-08        338272   6948945
# 2026-09-09        325637  12001620
# 2026-09-10        270894   9586645
# 2026-09-11        223277   8484897
#
# [501 rows x 251 columns]>

# %%
date_df = raw_data.loc["2026-09-11"].unstack(level='Ticker')
print(date_df.shape)

date_df
# Out:
# (6, 50)
# Ticker     ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# Price
# Adj Close          NaN            NaN            NaN            NaN
# Close           3060.0   1.764600e+03         8836.0    2472.500000
# High            3065.0   1.771900e+03         8950.0    2472.500000
# Low             2999.0   1.750800e+03         8806.0    2442.800049
# Open            3040.0   1.755000e+03         8806.0    2453.199951
# Volume       1815342.0   1.674823e+06       207930.0  653006.000000
#
# Ticker      AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJFINANCE.NS  \
# Price
# Adj Close           NaN            NaN            NaN            NaN
# Close      1.246000e+03        11678.0    1913.500000   1.034500e+03
# High       1.252800e+03        11723.0    1926.000000   1.035000e+03
# Low        1.229800e+03        11529.0    1895.000000   1.015100e+03
# Open       1.237900e+03        11624.0    1912.099976   1.031000e+03
# Volume     4.562285e+06       214731.0  762375.000000   5.411299e+06
#
# Ticker           BEL.NS  BHARTIARTL.NS  ...  SUNPHARMA.NS  TATACONSUM.NS  \
# Price                                   ...
# Adj Close           NaN            NaN  ...           NaN            NaN
# Close      4.043500e+02   1.831100e+03  ...        1840.0          991.0
# High       4.054000e+02   1.852000e+03  ...        1854.5         1000.0
# Low        3.992500e+02   1.830500e+03  ...        1834.0          988.0
# Open       4.026000e+02   1.832000e+03  ...        1845.0          993.0
# Volume     7.805974e+06   4.181325e+06  ...     1445071.0       905959.0
#
# Ticker     TATAMOTORS.NS  TATASTEEL.NS        TCS.NS      TECHM.NS  TITAN.NS  \
# Price
# Adj Close            NaN           NaN           NaN           NaN       NaN
# Close                NaN  1.830000e+02  2.200800e+03  1.541000e+03    5009.5
# High                 NaN  1.842400e+02  2.232600e+03  1.557300e+03    5015.0
# Low                  NaN  1.807900e+02  2.185500e+03  1.518600e+03    4943.0
# Open                 NaN  1.840000e+02  2.185500e+03  1.519300e+03    4964.0
# Volume               NaN  3.151021e+07  2.634124e+06  2.007328e+06  403235.0
#
# Ticker          TRENT.NS  ULTRACEMCO.NS      WIPRO.NS
# Price
# Adj Close            NaN            NaN           NaN
# Close        2802.399902        11000.0  1.674000e+02
# High         2816.000000        11060.0  1.677500e+02
# Low          2757.500000        10790.0  1.651600e+02
# Open         2789.000000        10859.0  1.652000e+02
# Volume     677898.000000       223277.0  8.484897e+06
#
# [6 rows x 50 columns]
